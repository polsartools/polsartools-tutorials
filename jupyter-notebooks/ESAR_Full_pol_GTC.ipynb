# %% [markdown]
# ## How to Use the Notebooks
#
# To run these notebooks, follow these steps:
#
#
# ### 1. Install **`gdal`** Package
# Installing `gdal` via `pip` may fail. Therefore, we recommend using conda to install it:
# ```bash
# conda install gdal -c conda-forge
# ```
#
# ### 2. Install **`polsartools`** Package
#
# Before running the notebooks, you'll need to install the core **`polsartools`** package.
#
# **Option A:** Install from PyPI `pip` (stable release)
#
# ```bash
# pip install polsartools
# ```
#
# **Option B:** Install from conda (stable release)
#
# ```bash
# conda install polsartools -c bnarayanarao
# ```
#
#
# **Option C:**  Install the latest version from GitHub (if you need recent updates or fixes)
#
# ```bash
# pip install git+https://github.com/Narayana-Rao/polsartools.git#egg=polsartools
# ```
# > **Note:** If you encounter a `"module not found"` error or require newer features, prefer the **Option C**.
#
# ### 3. Verify the Installation
#
# After successfully installing `polsartools`, you can verify it by importing the package:
#
# ```bash
# import polsartools as pst
# ```
#
# If this runs without errors, you're ready to explore and run the notebooks.

# %%
import os
from osgeo import gdal
import matplotlib.pyplot as plt
import numpy as np
import polsartools as pst

# %%
""" 

Function to display images

"""

def plot_images(*filenames, lower_percentile=2, upper_percentile=98, max_cols=4):
    def compute_vmin_vmax(data):
        data_no_nan = data[np.isfinite(data)]
        vmin = np.percentile(data_no_nan, lower_percentile)
        vmax = np.percentile(data_no_nan, upper_percentile)
        return vmin, vmax

    num_images = len(filenames)

    if num_images == 1:
        # Single image case
        data = pst.read_rst(filenames[0])
        data[data==0]=np.nan
        vmin, vmax = compute_vmin_vmax(data)

        fig, ax = plt.subplots(figsize=(6, 6))
        im = ax.imshow(data, vmin=vmin, vmax=vmax)
        ax.set_title(os.path.basename(filenames[0]))
        fig.colorbar(im, ax=ax)
        plt.tight_layout()
        plt.show()
    else:
        # Multiple image case
        ncols = min(max_cols, num_images)
        nrows = int(np.ceil(num_images / ncols))

        fig, axes = plt.subplots(nrows, ncols, figsize=(5 * ncols, 5 * nrows))
        axes = np.array(axes).reshape(-1)  # Flatten in case it's a 2D grid

        for i, filename in enumerate(filenames):
            data = pst.read_rst(filename)
            data[data==0]=np.nan
            vmin, vmax = compute_vmin_vmax(data)
            ax = axes[i]
            im = ax.imshow(data, vmin=vmin, vmax=vmax)
            ax.set_title(os.path.basename(filename))
            fig.colorbar(im, ax=ax)

        for j in range(num_images, len(axes)):
            axes[j].axis('off')

        plt.tight_layout()
        plt.show()

# %% [markdown]
# #### 1. Extract multilooked T3/C3 matrix elements

# %%
# Provide path to the extracted folder
data_dir = r"../data/ESAR/L-band/06agrsar0208x1_t01"

#The following function extracts single look S2 or mulit-looked C4/C3/T4/T3 matrix from ESAR GTC FP data

pst.import_esar_gtc(data_dir,mat='C3',azlks=5,rglks=5)
# Out:
# Detected L-band ['HH', 'HV', 'VV', 'VH']
# Progress: 100%|█████████████████████████████████████████████████████████████| 36/36 [00:00<00:00, 73.73block/s]
# Saved file ../data/ESAR/L-band/06agrsar0208x1_t01/C3/C11.tif
# Saved file ../data/ESAR/L-band/06agrsar0208x1_t01/C3/C12_real.tif
# Saved file ../data/ESAR/L-band/06agrsar0208x1_t01/C3/C12_imag.tif
# Saved file ../data/ESAR/L-band/06agrsar0208x1_t01/C3/C13_real.tif
# Saved file ../data/ESAR/L-band/06agrsar0208x1_t01/C3/C13_imag.tif
# Saved file ../data/ESAR/L-band/06agrsar0208x1_t01/C3/C22.tif
# Saved file ../data/ESAR/L-band/06agrsar0208x1_t01/C3/C23_real.tif
# Saved file ../data/ESAR/L-band/06agrsar0208x1_t01/C3/C23_imag.tif
# Saved file ../data/ESAR/L-band/06agrsar0208x1_t01/C3/C33.tif
# Execution time for convert_S: 0.00 seconds
# Execution time for import_esar_gtc: 1.00 seconds

# %% [markdown]
# #### 2. Speckle filtering using polarimetric refined-Lee filter (optional)

# %%
"""
The following function generates speckle filtered polarimetric matrices using the refined Lee polarimetric speckle filter: 
        
input C3/T3/C2/T2 folder path, and window_size 
"""

C3Folder = os.path.join(data_dir,'C3')
window_size = 3
pst.filter_refined_lee(C3Folder,win=window_size)
# Out:
# Progress: 100%|███████████████████████████████████████████████████████████████| 2/2 [00:00<00:00,  5.80block/s]
# Saved file ../data/ESAR/L-band/06agrsar0208x1_t01/rlee_3x3/C3/C11.tif
# Saved file ../data/ESAR/L-band/06agrsar0208x1_t01/rlee_3x3/C3/C12_real.tif
# Saved file ../data/ESAR/L-band/06agrsar0208x1_t01/rlee_3x3/C3/C12_imag.tif
# Saved file ../data/ESAR/L-band/06agrsar0208x1_t01/rlee_3x3/C3/C13_real.tif
# Saved file ../data/ESAR/L-band/06agrsar0208x1_t01/rlee_3x3/C3/C13_imag.tif
# Saved file ../data/ESAR/L-band/06agrsar0208x1_t01/rlee_3x3/C3/C22.tif
# Saved file ../data/ESAR/L-band/06agrsar0208x1_t01/rlee_3x3/C3/C23_real.tif
# Saved file ../data/ESAR/L-band/06agrsar0208x1_t01/rlee_3x3/C3/C23_imag.tif
# Saved file ../data/ESAR/L-band/06agrsar0208x1_t01/rlee_3x3/C3/C33.tif
# Execution time for filter_refined_lee: 0.00 seconds

# %% [markdown]
# #### 3. Generate a quick look Pauli RGB from C3/T3 matrix (optional)

# %%
# update the C3 folder based on your folder
C3Folder = os.path.join(data_dir,'rlee_3x3','C3')

pst.pauli_rgb(C3Folder)
# Out:
# Pauli RGB image saved as ../data/ESAR/L-band/06agrsar0208x1_t01/rlee_3x3/C3/PauliRGB.png
# Execution time for pauli_rgb: 0.00 seconds

# %% [markdown]
# #### 4. Generating Decomposition parameters

# %% [markdown]
# #### 4.1. Generate H/A/α Decomposition parameters

# %%
"""
The following function generates H/A/alpha decomposition parameters: 
        Alpha, entropy, anisotropy and 
        normalized eigen values e1_norm, e2_norm, e3_norm in geotif format

input C3/T3 folder path, window_size is optional  

"""

pst.h_a_alpha_fp(C3Folder,win=3) 


### Plotting
plot_images(os.path.join(C3Folder,'H_fp.tif'),
             os.path.join(C3Folder,'anisotropy_fp.tif'),
              os.path.join(C3Folder,'alpha_fp.tif'))

plot_images(os.path.join(C3Folder,'e1_norm.tif'),
             os.path.join(C3Folder,'e2_norm.tif'),
             os.path.join(C3Folder,'e3_norm.tif'))
# Out:
# Progress: 100%|███████████████████████████████████████████████████████████████| 2/2 [00:00<00:00,  2.41block/s]
# Saved file ../data/ESAR/L-band/06agrsar0208x1_t01/rlee_3x3/C3/H_fp.tif
# Saved file ../data/ESAR/L-band/06agrsar0208x1_t01/rlee_3x3/C3/alpha_fp.tif
# Saved file ../data/ESAR/L-band/06agrsar0208x1_t01/rlee_3x3/C3/anisotropy_fp.tif
# Saved file ../data/ESAR/L-band/06agrsar0208x1_t01/rlee_3x3/C3/e1_norm.tif
# Saved file ../data/ESAR/L-band/06agrsar0208x1_t01/rlee_3x3/C3/e2_norm.tif
# Saved file ../data/ESAR/L-band/06agrsar0208x1_t01/rlee_3x3/C3/e3_norm.tif
# Execution time for h_a_alpha_fp: 0.00 seconds

# %% [markdown]
# #### Plot Entropy-Alpha 2D plane

# %%
hFile = C3Folder + '/H_fp.tif'
alphaFile = C3Folder + '/alpha_fp.tif'

pst.plot_h_alpha_fp(hFile,alphaFile,cmap='jet',               
                   norm='log',
                   # ppath = '',# give a name.png to save the plot as png 
                  zone_lines=True,
                  zone_ids=False,)

# %% [markdown]
# #### Plot a 3D Entropy-Anisotropy-Alpha plot

# %%
hFile = C3Folder + '/H_fp.tif'
aFile = C3Folder + '/anisotropy_fp.tif'
alphaFile = C3Folder + '/alpha_fp.tif'

pst.plot_h_a_alpha_fp(hFile,aFile,alphaFile,cmap='jet',               
                   norm='log',
                   # ppath = '',# give a name.png to save the plot as png 
                  zone_lines=True,
                  # zone_ids=False,
                   )
# Out:
# Execution time for plot_h_a_alpha_fp: 1.00 seconds

# %% [markdown]
# #### 4.2. Generate Yamaguchi 4-Component Decomposition parameters

# %%
"""
The following function generates Yamaguchi 4-Component Decomposition parameters: 
        Yam4co_odd, Yam4co_dbl, Yam4co_vol and Yam4co_hlx in geotif format

input C3/T3 folder path, window_size is optional  

"""

pst.yamaguchi_4c(C3Folder,win=3)
# Out:
# Progress: 100%|███████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 14.38block/s]
# Saved file ../data/ESAR/L-band/06agrsar0208x1_t01/rlee_3x3/C3/Yam4co_odd.tif
# Saved file ../data/ESAR/L-band/06agrsar0208x1_t01/rlee_3x3/C3/Yam4co_dbl.tif
# Saved file ../data/ESAR/L-band/06agrsar0208x1_t01/rlee_3x3/C3/Yam4co_vol.tif
# Saved file ../data/ESAR/L-band/06agrsar0208x1_t01/rlee_3x3/C3/Yam4co_hlx.tif
# Execution time for yamaguchi_4c: 0.00 seconds

# %%
### Plotting
plot_images(os.path.join(C3Folder,'Yam4co_odd.tif'),
            os.path.join(C3Folder,'Yam4co_dbl.tif'),
            os.path.join(C3Folder,'Yam4co_vol.tif'),
            os.path.join(C3Folder,'Yam4co_hlx.tif'),
           )

# %% [markdown]
# #### Create False colour RGB from decomposed powers

# %%
blue = os.path.join(C3Folder,'Yam4co_odd.tif')
red = os.path.join(C3Folder,'Yam4co_dbl.tif')
green = os.path.join(C3Folder,'Yam4co_vol.tif')

pst.rgb(red,green,blue)
# Out:
# RGB image saved as ../data/ESAR/L-band/06agrsar0208x1_t01/rlee_3x3/C3/RGB.png
# Execution time for rgb: 0.00 seconds
