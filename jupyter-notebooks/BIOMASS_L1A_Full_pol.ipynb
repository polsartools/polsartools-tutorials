# %% [markdown]
# ## How to Use the Notebooks
#
# To run these notebooks, follow these steps:
#
#
# ### 1. Install **`gdal`** Package
# Installing `gdal` via `pip` may fail. Therefore, we recommend using conda to install it:
# ```bash
# conda install gdal -c conda-forge
# ```
#
# ### 2. Install **`polsartools`** Package
#
# Before running the notebooks, you'll need to install the core **`polsartools`** package.
#
# **Option A:** Install from PyPI `pip` (stable release)
#
# ```bash
# pip install polsartools
# ```
#
# **Option B:** Install from conda (stable release)
#
# ```bash
# conda install polsartools -c bnarayanarao
# ```
#
#
# **Option C:**  Install the latest version from GitHub (if you need recent updates or fixes)
#
# ```bash
# pip install git+https://github.com/Narayana-Rao/polsartools.git#egg=polsartools
# ```
# > **Note:** If you encounter a `"module not found"` error or require newer features, prefer the **Option C**.
#
# ### 3. Verify the Installation
#
# After successfully installing `polsartools`, you can verify it by importing the package:
#
# ```bash
# import polsartools as pst
# ```
#
# If this runs without errors, you're ready to explore and run the notebooks.

# %%
import polsartools as pst
import os
from osgeo import gdal
import matplotlib.pyplot as plt
import numpy as np
import warnings
warnings.filterwarnings("ignore")

# %%
""" 

Function to display images

"""

def plot_images(*filenames, lower_percentile=2, upper_percentile=98, max_cols=4):
    def compute_vmin_vmax(data):
        data_no_nan = data[np.isfinite(data)]
        vmin = np.percentile(data_no_nan, lower_percentile)
        vmax = np.percentile(data_no_nan, upper_percentile)
        return vmin, vmax

    num_images = len(filenames)

    if num_images == 1:
        # Single image case
        data = pst.read_rst(filenames[0])
        data[data==0]=np.nan
        vmin, vmax = compute_vmin_vmax(data)

        fig, ax = plt.subplots(figsize=(6, 6))
        im = ax.imshow(data, vmin=vmin, vmax=vmax)
        ax.set_title(os.path.basename(filenames[0]))
        fig.colorbar(im, ax=ax)
        plt.tight_layout()
        plt.show()
    else:
        # Multiple image case
        ncols = min(max_cols, num_images)
        nrows = int(np.ceil(num_images / ncols))

        fig, axes = plt.subplots(nrows, ncols, figsize=(5 * ncols, 5 * nrows))
        axes = np.array(axes).reshape(-1)  # Flatten in case it's a 2D grid

        for i, filename in enumerate(filenames):
            data = pst.read_rst(filename)
            data[data==0]=np.nan
            vmin, vmax = compute_vmin_vmax(data)
            ax = axes[i]
            im = ax.imshow(data, vmin=vmin, vmax=vmax)
            ax.set_title(os.path.basename(filename))
            fig.colorbar(im, ax=ax)

        for j in range(num_images, len(axes)):
            axes[j].axis('off')

        plt.tight_layout()
        plt.show()

# %% [markdown]
# #### 1. Extract multilooked C4/C3/T4/T3 matrix from BIOMASS L1-A full-pol GSLC data

# %%
"""
The following function extracts a single-look S2 or multilooked C4/C3/T4/T3 matrix from BIOMASS L1-A full-polarimetric data. 

Provide the path to the extracted BIOMASS L1A directory.
"""

in_dir =r"./BIO_S1_SCS__1S_20251130T001015_20251130T001043_T_G01_M01_C03_T001_F016_01_DKO1MI"

pst.import_biomass_l1a(in_dir,azlks=12,rglks=3,mat='C3',
                      fmt='tif', # output format tif//bin
                      cog=False, ovr=[2, 4, 8, 16], # COG prameters
                      comp=False, # Tiff compression (optional)
                      out_dir=None, # output path to save the extracted matrix (default is input directory)
                      recip=False, # Scatterin reciprocity for S2, C4/T4 matrices 
                     )
# Out:
# Extracting single-look elements...
# Progress: 100%|██████████████████████████████████████████████████████████████████████████████████████████████| 171/171 [00:02<00:00, 76.15block/s]
# Saved file ./BIO_S1_SCS__1S_20251130T001015_20251130T001043_T_G01_M01_C03_T001_F016_01_DKO1MI/C3/C11.tif
# Saved file ./BIO_S1_SCS__1S_20251130T001015_20251130T001043_T_G01_M01_C03_T001_F016_01_DKO1MI/C3/C12_real.tif
# Saved file ./BIO_S1_SCS__1S_20251130T001015_20251130T001043_T_G01_M01_C03_T001_F016_01_DKO1MI/C3/C12_imag.tif
# Saved file ./BIO_S1_SCS__1S_20251130T001015_20251130T001043_T_G01_M01_C03_T001_F016_01_DKO1MI/C3/C13_real.tif
# Saved file ./BIO_S1_SCS__1S_20251130T001015_20251130T001043_T_G01_M01_C03_T001_F016_01_DKO1MI/C3/C13_imag.tif
# Saved file ./BIO_S1_SCS__1S_20251130T001015_20251130T001043_T_G01_M01_C03_T001_F016_01_DKO1MI/C3/C22.tif
# Saved file ./BIO_S1_SCS__1S_20251130T001015_20251130T001043_T_G01_M01_C03_T001_F016_01_DKO1MI/C3/C23_real.tif
# Saved file ./BIO_S1_SCS__1S_20251130T001015_20251130T001043_T_G01_M01_C03_T001_F016_01_DKO1MI/C3/C23_imag.tif
# Saved file ./BIO_S1_SCS__1S_20251130T001015_20251130T001043_T_G01_M01_C03_T001_F016_01_DKO1MI/C3/C33.tif
# Execution time for convert_S: 2.00 seconds
# Execution time for import_biomass_l1a: 5.00 seconds

# %% [markdown]
# #### 2. Speckle filtering using polarimetric refined-Lee filter

# %%
C3Folder = os.path.join(in_dir,'C3')
window_size = 3
pst.filter_refined_lee(C3Folder,win=window_size,
                    fmt='tif', # output format tif//bin
                  sub_dir=True, # creates a sub directory with filtered data
                  cog=False, ovr=[2, 4, 8, 16], # COG prameters
                  comp=False, # Tiff compression (optional)
                      )
# Out:
# Progress: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00,  8.36block/s]
# Saved file ./BIO_S1_SCS__1S_20251130T001015_20251130T001043_T_G01_M01_C03_T001_F016_01_DKO1MI/rlee_3x3/C3/C11.tif
# Saved file ./BIO_S1_SCS__1S_20251130T001015_20251130T001043_T_G01_M01_C03_T001_F016_01_DKO1MI/rlee_3x3/C3/C12_real.tif
# Saved file ./BIO_S1_SCS__1S_20251130T001015_20251130T001043_T_G01_M01_C03_T001_F016_01_DKO1MI/rlee_3x3/C3/C12_imag.tif
# Saved file ./BIO_S1_SCS__1S_20251130T001015_20251130T001043_T_G01_M01_C03_T001_F016_01_DKO1MI/rlee_3x3/C3/C13_real.tif
# Saved file ./BIO_S1_SCS__1S_20251130T001015_20251130T001043_T_G01_M01_C03_T001_F016_01_DKO1MI/rlee_3x3/C3/C13_imag.tif
# Saved file ./BIO_S1_SCS__1S_20251130T001015_20251130T001043_T_G01_M01_C03_T001_F016_01_DKO1MI/rlee_3x3/C3/C22.tif
# Saved file ./BIO_S1_SCS__1S_20251130T001015_20251130T001043_T_G01_M01_C03_T001_F016_01_DKO1MI/rlee_3x3/C3/C23_real.tif
# Saved file ./BIO_S1_SCS__1S_20251130T001015_20251130T001043_T_G01_M01_C03_T001_F016_01_DKO1MI/rlee_3x3/C3/C23_imag.tif
# Saved file ./BIO_S1_SCS__1S_20251130T001015_20251130T001043_T_G01_M01_C03_T001_F016_01_DKO1MI/rlee_3x3/C3/C33.tif
# Execution time for filter_refined_lee: 0.00 seconds

# %% [markdown]
# #### 3. Generate a quick look Pauli RGB from the extracted matrix

# %%
C3Folder = os.path.join(in_dir,f"rlee_{window_size}x{window_size}",'C3')
pst.pauli_rgb(C3Folder)
# Out:
# Pauli RGB image saved as ./BIO_S1_SCS__1S_20251130T001015_20251130T001043_T_G01_M01_C03_T001_F016_01_DKO1MI/rlee_3x3/C3/PauliRGB.png
# Execution time for pauli_rgb: 0.00 seconds

# %% [markdown]
# #### 4. Generating Decomposition parameters

# %% [markdown]
# #### 4.1. Generate H/A/α Decomposition parameters

# %%
"""
The following function generates H/A/alpha decomposition parameters: 
        Alpha, entropy, anisotropy, and 
        normalized eigen values e1_norm, e2_norm, e3_norm in geotif format

input C3/T3 folder path, window_size is optional  

"""
# update the C3 folder based on your folder

pst.h_a_alpha_fp(C3Folder,win=3) 


### Plotting
plot_images(os.path.join(C3Folder,'H_fp.tif'),
             os.path.join(C3Folder,'anisotropy_fp.tif'),
              os.path.join(C3Folder,'alpha_fp.tif'))

plot_images(os.path.join(C3Folder,'e1_norm.tif'),
             os.path.join(C3Folder,'e2_norm.tif'),
             os.path.join(C3Folder,'e3_norm.tif'))
# Out:
# Progress: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:01<00:00,  3.64block/s]
# Saved file ./BIO_S1_SCS__1S_20251130T001015_20251130T001043_T_G01_M01_C03_T001_F016_01_DKO1MI/rlee_3x3/C3/H_fp.tif
# Saved file ./BIO_S1_SCS__1S_20251130T001015_20251130T001043_T_G01_M01_C03_T001_F016_01_DKO1MI/rlee_3x3/C3/alpha_fp.tif
# Saved file ./BIO_S1_SCS__1S_20251130T001015_20251130T001043_T_G01_M01_C03_T001_F016_01_DKO1MI/rlee_3x3/C3/anisotropy_fp.tif
# Saved file ./BIO_S1_SCS__1S_20251130T001015_20251130T001043_T_G01_M01_C03_T001_F016_01_DKO1MI/rlee_3x3/C3/e1_norm.tif
# Saved file ./BIO_S1_SCS__1S_20251130T001015_20251130T001043_T_G01_M01_C03_T001_F016_01_DKO1MI/rlee_3x3/C3/e2_norm.tif
# Saved file ./BIO_S1_SCS__1S_20251130T001015_20251130T001043_T_G01_M01_C03_T001_F016_01_DKO1MI/rlee_3x3/C3/e3_norm.tif
# Execution time for h_a_alpha_fp: 1.00 seconds

# %% [markdown]
# #### Plot Entropy-Alpha 2D plane

# %%
hFile = C3Folder + '/H_fp.tif'
alphaFile = C3Folder + '/alpha_fp.tif'
out_path = C3Folder + '/halpha_fp.png'
pst.plot_h_alpha_fp(hFile,alphaFile,cmap='jet',               
                   norm='log',
                   ppath = out_path,# give a name.png to save the plot as png 
                  zone_lines=True,
                  zone_ids=False,)

# %% [markdown]
# #### Plot a 3D Entropy-Anisotropy-Alpha plot

# %%
hFile = C3Folder + '/H_fp.tif'
aFile = C3Folder + '/anisotropy_fp.tif'
alphaFile = C3Folder + '/alpha_fp.tif'
out_path = C3Folder + '/haalpha_fp.png'

pst.plot_h_a_alpha_fp(hFile,aFile,alphaFile,cmap='jet',               
                   norm='log',
                   ppath = out_path,# give a name.png to save the plot as png 
                  zone_lines=True,
                  # zone_ids=False,
                   )
# Out:
# Execution time for plot_h_a_alpha_fp: 9.00 seconds

# %% [markdown]
# #### 4.2. Generate model-free 3-component decomposition parameters

# %%
"""
The following function generates model-free/non-model 3-component decomposition parameters: 
        Ps_mf3cf, Pd_mf3cf, Pv_mf3cf and Theta_FP_mf3cf in geotif format

input C3/T3 folder path, window_size is optional  

"""

pst.mf3cf(C3Folder,win=3) 


### Plotting
plot_images(os.path.join(C3Folder,'Ps_mf3cf.tif'),
             os.path.join(C3Folder,'Pd_mf3cf.tif'),
              os.path.join(C3Folder,'Pv_mf3cf.tif'),
           os.path.join(C3Folder,'Theta_FP_mf3cf.tif'))
# Out:
# Progress: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 14.75block/s]
# Saved file ./BIO_S1_SCS__1S_20251130T001015_20251130T001043_T_G01_M01_C03_T001_F016_01_DKO1MI/rlee_3x3/C3/Ps_mf3cf.tif
# Saved file ./BIO_S1_SCS__1S_20251130T001015_20251130T001043_T_G01_M01_C03_T001_F016_01_DKO1MI/rlee_3x3/C3/Pd_mf3cf.tif
# Saved file ./BIO_S1_SCS__1S_20251130T001015_20251130T001043_T_G01_M01_C03_T001_F016_01_DKO1MI/rlee_3x3/C3/Pv_mf3cf.tif
# Saved file ./BIO_S1_SCS__1S_20251130T001015_20251130T001043_T_G01_M01_C03_T001_F016_01_DKO1MI/rlee_3x3/C3/Theta_FP_mf3cf.tif
# Execution time for mf3cf: 0.00 seconds

# %% [markdown]
# #### Plot Entropy-Theta on 2D plane
#
# Note: $\overline{H}=1-H$ and $\overline{\theta}_{FP}=2*\theta$

# %%
hFile = C3Folder + '/H_fp.tif'
thetaFile = C3Folder + '/Theta_FP_mf3cf.tif'

pst.plot_h_theta_fp(hFile, thetaFile,
                  norm='log',
                  )

# %% [markdown]
# #### Create False colour RGB from decomposed powers

# %%
blue = os.path.join(C3Folder,'Ps_mf3cf.tif')
red = os.path.join(C3Folder,'Pd_mf3cf.tif')
green = os.path.join(C3Folder,'Pv_mf3cf.tif')

pst.rgb(red,green,blue)
# Out:
# RGB image saved as ./BIO_S1_SCS__1S_20251130T001015_20251130T001043_T_G01_M01_C03_T001_F016_01_DKO1MI/rlee_3x3/C3/RGB.png
# Execution time for rgb: 0.00 seconds

# %% [markdown]
# #### 4.3. Generate Yamaguchi 4-Component Decomposition parameters

# %%
"""
The following function generates Yamaguchi 4-Component Decomposition parameters: 
        Yam4co_odd, Yam4co_dbl, Yam4co_vol and Yam4co_hlx in geotif format

input C3/T3 folder path, window_size is optional  

"""

pst.yamaguchi_4c(C3Folder,win=3)
# Out:
# Progress: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 17.57block/s]
# Saved file ./BIO_S1_SCS__1S_20251130T001015_20251130T001043_T_G01_M01_C03_T001_F016_01_DKO1MI/rlee_3x3/C3/Yam4co_odd.tif
# Saved file ./BIO_S1_SCS__1S_20251130T001015_20251130T001043_T_G01_M01_C03_T001_F016_01_DKO1MI/rlee_3x3/C3/Yam4co_dbl.tif
# Saved file ./BIO_S1_SCS__1S_20251130T001015_20251130T001043_T_G01_M01_C03_T001_F016_01_DKO1MI/rlee_3x3/C3/Yam4co_vol.tif
# Saved file ./BIO_S1_SCS__1S_20251130T001015_20251130T001043_T_G01_M01_C03_T001_F016_01_DKO1MI/rlee_3x3/C3/Yam4co_hlx.tif
# Execution time for yamaguchi_4c: 0.00 seconds

# %%
### Plotting
plot_images(os.path.join(C3Folder,'Yam4co_odd.tif'),
            os.path.join(C3Folder,'Yam4co_dbl.tif'),
            os.path.join(C3Folder,'Yam4co_vol.tif'),
            os.path.join(C3Folder,'Yam4co_hlx.tif'),
           )

# %% [markdown]
# #### Create False colour RGB from decomposed powers

# %%
blue = os.path.join(C3Folder,'Yam4co_odd.tif')
red = os.path.join(C3Folder,'Yam4co_dbl.tif')
green = os.path.join(C3Folder,'Yam4co_vol.tif')

pst.rgb(red,green,blue)
# Out:
# RGB image saved as ./BIO_S1_SCS__1S_20251130T001015_20251130T001043_T_G01_M01_C03_T001_F016_01_DKO1MI/rlee_3x3/C3/RGB.png
# Execution time for rgb: 0.00 seconds
